# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from explainability.model_card import ModelCard

card = ModelCard(
    model_name="Healthcare Cost Prediction",
    version="2.0",
    algorithm="Stacking Ensemble (XGBoost + LightGBM)"
)

card.set_dataset(
    name="Synthetic Patient Financial Risk Dataset",
    records=10000,
    description="Synthetic healthcare and financial dataset."
)

card.set_performance(
    mae=1316.53,
    rmse=1791.19,
    r2=0.9617
)

card.add_features([
    "Age",
    "BMI",
    "Hospital Visits",
    "Medication Count",
    "Annual Claim Amount",
    "Health Risk Score",
    "Claims-to-Premium Ratio",
])

card.set_intended_use(
    "Estimate future healthcare costs to support operational planning, financial forecasting, and risk stratification. This model is intended to assist decision-making and should not be used as the sole basis for clinical diagnosis or treatment."
)

card.add_limitations([
    "Trained on synthetic data.",
    "Predictions may not generalize to real-world populations without retraining.",
    "Not intended for clinical diagnosis."
])

card.add_ethics([
    "Do not use predictions as the sole basis for healthcare decisions.",
    "Review outputs with qualified healthcare professionals.",
    "Monitor model performance and fairness after deployment."
])

json_path = card.save_json(PROJECT_ROOT / "reports")
md_path = card.save_markdown(PROJECT_ROOT / "reports")

print(json_path)
print(md_path)
# Out:
# c:\Users\Mirza Shareef Baig\OneDrive\Desktop\Healthrisk-ai\reports\model_card.json
# c:\Users\Mirza Shareef Baig\OneDrive\Desktop\Healthrisk-ai\reports\model_card.md
