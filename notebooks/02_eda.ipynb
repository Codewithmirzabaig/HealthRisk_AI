# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\Mirza Shareef Baig\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\Mirza Shareef Baig\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Mirza Shareef Baig\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Mirza Shareef Baig\AppData\Roaming\Python\Python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\Mirza Shareef Baig\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Mirza Shareef Baig\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
print(os.getcwd())

df = pd.read_csv("data/raw/patient_financial_risk.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nRisk Distribution:")
print(df["risk_level"].value_counts())

print("\nSummary Statistics:")
print(df.describe())
# Out:
# c:\Users\Mirza Shareef Baig\OneDrive\Desktop\Healthrisk-ai\notebooks
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 import os
#       3 print(os.getcwd())
# ----> 5 df = pd.read_csv("data/raw/patient_financial_risk.csv")
#       7 print("Shape:", df.shape)
#       8 print("\nColumns:")
#
# File c:\Users\Mirza Shareef Baig\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Mirza Shareef Baig\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Mirza Shareef Baig\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Mirza Shareef Baig\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Mirza Shareef Baig\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/patient_financial_risk.csv'

# %%
import os

print("Current Directory:")
print(os.getcwd())

print("\nFiles Here:")
print(os.listdir())
# Out:
# Current Directory:
# c:\Users\Mirza Shareef Baig\OneDrive\Desktop\Healthrisk-ai\notebooks
#
# Files Here:
# ['01_data_generation.ipynb', '02_eda.ipynb']

# %%
import pandas as pd

df = pd.read_csv("../data/raw/patient_financial_risk.csv")

print(df.shape)
print(df.head())
# Out:
# (10000, 19)
#    patient_id  age  gender   bmi  smoker  diabetes  hypertension  \
# 0           1   69  Female  25.3       0         0             1
# 1           2   32    Male  31.0       0         0             0
# 2           3   89    Male  39.2       0         0             1
# 3           4   78  Female  25.2       0         1             0
# 4           5   38  Female  36.3       0         0             0
#
#    heart_disease  hospital_visits  medication_count  annual_claim_amount  \
# 0              1                1                 3             19025.31
# 1              0                1                 1              8822.49
# 2              0                1                 3             11264.47
# 3              1                4                 5             30571.22
# 4              0                2                 1              9321.35
#
#    premium_paid  hospital_rating  hospital_debt_ratio  \
# 0          9505                1                 0.29
# 1          4440                1                 0.42
# 2          7905                1                 0.41
# 3         10810                3                 0.58
# 4          4710                3                 0.53
#
#    pharma_investment_score  esg_score  pandemic_risk_index  \
# 0                    19.69      84.55                0.511
# 1                     2.03      66.94                0.801
# 2                    27.45      61.35                0.410
# 3                    95.81      67.46                0.275
# 4                    57.89      35.44                0.942
#
#    future_health_cost risk_level
# 0            27769.38       High
# 1            13585.13        Low
# 2            17540.43     Medium
# 3            40978.02       High
# 4            14812.69     Medium

# %%
import os

print(os.path.exists("../data/raw/patient_financial_risk.csv"))
# Out:
# True

# %%
print(df.shape)
print(df["risk_level"].value_counts())
print(df.describe())
# Out:
# (10000, 19)
# risk_level
# Medium    4180
# Low       3768
# High      2052
# Name: count, dtype: int64
#         patient_id           age           bmi        smoker      diabetes  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    5000.50000     53.539700     27.994390      0.181900      0.240300
# std     2886.89568     20.757324      5.846884      0.385781      0.427287
# min        1.00000     18.000000     16.000000      0.000000      0.000000
# 25%     2500.75000     36.000000     23.800000      0.000000      0.000000
# 50%     5000.50000     53.000000     27.950000      0.000000      0.000000
# 75%     7500.25000     72.000000     31.900000      0.000000      0.000000
# max    10000.00000     89.000000     49.300000      1.000000      1.000000
#
#        hypertension  heart_disease  hospital_visits  medication_count  \
# count  10000.000000    10000.00000     10000.000000      10000.000000
# mean       0.322000        0.13020         1.907000          2.232600
# std        0.467266        0.33654         1.719548          2.112189
# min        0.000000        0.00000         0.000000          0.000000
# 25%        0.000000        0.00000         1.000000          1.000000
# 50%        0.000000        0.00000         2.000000          2.000000
# 75%        1.000000        0.00000         3.000000          3.000000
# max        1.000000        1.00000        13.000000         15.000000
#
#        annual_claim_amount  premium_paid  hospital_rating  \
# count         10000.000000  10000.000000     10000.000000
# mean          13749.834783   6675.406500         2.992400
# std            7209.934758   2058.169439         1.412849
# min             500.000000   3810.000000         1.000000
# 25%            8556.550000   4980.000000         2.000000
# 50%           12476.980000   6285.000000         3.000000
# 75%           17843.435000   8025.000000         4.000000
# max           50589.400000  13405.000000         5.000000
#
#        hospital_debt_ratio  pharma_investment_score     esg_score  \
# count         10000.000000             10000.000000  10000.000000
# mean              0.501401                49.810026     49.445574
# std               0.202742                28.800771     28.918312
# min               0.150000                 0.030000      0.010000
# 25%               0.320000                24.940000     24.305000
# 50%               0.500000                49.890000     49.050000
# 75%               0.680000                74.542500     74.555000
# max               0.850000                99.980000    100.000000
#
#        pandemic_risk_index  future_health_cost
# count         10000.000000        10000.000000
# mean              0.496220        18691.243756
# std               0.287598         9222.134710
# min               0.000000          590.910000
# 25%               0.247000        11989.087500
# 50%               0.494000        17018.630000
# 75%               0.745000        23698.532500
# max               1.000000        67410.890000
